# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
from config import API_KEY
import requests
import json

# %%
file = 'constituents_csv.csv'

# %%
#setup DF from the csv

df = pd.read_csv(file)

# %%
df.head()
# Out:
#     Pro                 Name                  Sector
# 0   MMM           3M Company             Industrials
# 1   AOS      A.O. Smith Corp             Industrials
# 2   ABT  Abbott Laboratories             Health Care
# 3  ABBV          AbbVie Inc.             Health Care
# 4   ACN        Accenture plc  Information Technology

# %%
#Convert Data Frame to Dictionary (set_index method allows any column to be used as index)
df2dict=df.set_index('Pro').transpose().to_dict(orient='dict')

# %%
#print(df2dict)

# %%
#Python API from IEX
response = requests.get("https://cloud.iexapis.com/?token={$API_KEY}")
print(response.status_code)
# Out:
# 404

# %%
#create a for loop that returns each ticker so we can return financial information for each company and store it in a list
symbols = []
for key, value in df2dict.items():
    symbols.append(key)

# %%
print(symbols)
# Out:
# ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ATVI', 'AYI', 'ADBE', 'AAP', 'AMD', 'AES', 'AET', 'AMG', 'AFL', 'A', 'APD', 'AKAM', 'ALK', 'ALB', 'ARE', 'ALXN', 'ALGN', 'ALLE', 'AGN', 'ADS', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'ABC', 'AME', 'AMGN', 'APH', 'APC', 'ADI', 'ANDV', 'ANSS', 'ANTM', 'AON', 'APA', 'AIV', 'AAPL', 'AMAT', 'APTV', 'ADM', 'ARNC', 'AJG', 'AIZ', 'T', 'ADSK', 'ADP', 'AZO', 'AVB', 'AVY', 'BHGE', 'BLL', 'BAC', 'BAX', 'BBT', 'BDX', 'BRK.B', 'BBY', 'BIIB', 'BLK', 'HRB', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BHF', 'BMY', 'AVGO', 'BF.B', 'CHRW', 'CA', 'COG', 'CDNS', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CAT', 'CBOE', 'CBRE', 'CBS', 'CELG', 'CNC', 'CNP', 'CTL', 'CERN', 'CF', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'XEC', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CTXS', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'CXO', 'COP', 'ED', 'STZ', 'GLW', 'COST', 'COTY', 'CCI', 'CSRA', 'CSX', 'CMI', 'CVS', 'DHI', 'DHR', 'DRI', 'DVA', 'DE', 'DAL', 'XRAY', 'DVN', 'DLR', 'DFS', 'DISCA', 'DISCK', 'DISH', 'DG', 'DLTR', 'D', 'DOV', 'DWDP', 'DPS', 'DTE', 'DUK', 'DRE', 'DXC', 'ETFC', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'EMR', 'ETR', 'EVHC', 'EOG', 'EQT', 'EFX', 'EQIX', 'EQR', 'ESS', 'EL', 'RE', 'ES', 'EXC', 'EXPE', 'EXPD', 'ESRX', 'EXR', 'XOM', 'FFIV', 'FB', 'FAST', 'FRT', 'FDX', 'FIS', 'FITB', 'FE', 'FISV', 'FLIR', 'FLS', 'FLR', 'FMC', 'FL', 'F', 'FTV', 'FBHS', 'BEN', 'FCX', 'GPS', 'GRMN', 'IT', 'GD', 'GE', 'GGP', 'GIS', 'GM', 'GPC', 'GILD', 'GPN', 'GS', 'GT', 'GWW', 'HAL', 'HBI', 'HOG', 'HRS', 'HIG', 'HAS', 'HCA', 'HCP', 'HP', 'HSIC', 'HES', 'HPE', 'HLT', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'HPQ', 'HUM', 'HBAN', 'HII', 'IDXX', 'INFO', 'ITW', 'ILMN', 'INCY', 'IR', 'INTC', 'ICE', 'IBM', 'IP', 'IPG', 'IFF', 'INTU', 'ISRG', 'IVZ', 'IPGP', 'IQV', 'IRM', 'JBHT', 'JEC', 'SJM', 'JNJ', 'JCI', 'JPM', 'JNPR', 'KSU', 'K', 'KEY', 'KMB', 'KIM', 'KMI', 'KLAC', 'KSS', 'KHC', 'KR', 'LB', 'LLL', 'LH', 'LRCX', 'LEG', 'LEN', 'LUK', 'LLY', 'LNC', 'LKQ', 'LMT', 'L', 'LOW', 'LYB', 'MTB', 'MAC', 'M', 'MRO', 'MPC', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'MAT', 'MKC', 'MCD', 'MCK', 'MDT', 'MRK', 'MET', 'MTD', 'MGM', 'KORS', 'MCHP', 'MU', 'MSFT', 'MAA', 'MHK', 'TAP', 'MDLZ', 'MON', 'MNST', 'MCO', 'MS', 'MSI', 'MYL', 'NDAQ', 'NOV', 'NAVI', 'NKTR', 'NTAP', 'NFLX', 'NWL', 'NFX', 'NEM', 'NWSA', 'NWS', 'NEE', 'NLSN', 'NKE', 'NI', 'NBL', 'JWN', 'NSC', 'NTRS', 'NOC', 'NCLH', 'NRG', 'NUE', 'NVDA', 'ORLY', 'OXY', 'OMC', 'OKE', 'ORCL', 'PCAR', 'PKG', 'PH', 'PAYX', 'PYPL', 'PNR', 'PBCT', 'PEP', 'PKI', 'PRGO', 'PFE', 'PCG', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'RL', 'PPG', 'PPL', 'PX', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'PSA', 'PHM', 'PVH', 'QRVO', 'QCOM', 'PWR', 'DGX', 'RRC', 'RJF', 'RTN', 'O', 'RHT', 'REG', 'REGN', 'RF', 'RSG', 'RMD', 'RHI', 'ROK', 'COL', 'ROP', 'ROST', 'RCL', 'SPGI', 'CRM', 'SBAC', 'SCG', 'SLB', 'STX', 'SEE', 'SRE', 'SHW', 'SPG', 'SWKS', 'SLG', 'SNA', 'SO', 'LUV', 'SWK', 'SBUX', 'STT', 'SRCL', 'SYK', 'STI', 'SIVB', 'SYMC', 'SYF', 'SNPS', 'SYY', 'TROW', 'TTWO', 'TPR', 'TGT', 'TEL', 'FTI', 'TXN', 'TXT', 'BK', 'CLX', 'COO', 'HSY', 'MOS', 'TRV', 'DIS', 'TMO', 'TIF', 'TWX', 'TJX', 'TMK', 'TSS', 'TSCO', 'TDG', 'TRIP', 'FOXA', 'FOX', 'TSN', 'USB', 'UDR', 'ULTA', 'UAA', 'UA', 'UNP', 'UAL', 'UNH', 'UPS', 'URI', 'UTX', 'UHS', 'UNM', 'VFC', 'VLO', 'VAR', 'VTR', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VIAB', 'V', 'VNO', 'VMC', 'WMT', 'WBA', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'WDC', 'WU', 'WRK', 'WY', 'WHR', 'WMB', 'WLTW', 'WYN', 'WYNN', 'XEL', 'XRX', 'XLNX', 'XL', 'XYL', 'YUM', 'ZBH', 'ZION', 'ZTS']

# %%
#maybe pointless? want to tie the symbol to financial data. 

symbols2dict = dict.fromkeys(symbols)
#print(symbols2dict)

# %%
# reference the symbols list in the API call 

for symbol in symbols:
    response = requests.get(f'https://cloud.iexapis.com/beta/stock/{symbol}/quote?token={API_KEY}')
    response_json = response.json()
    print(json.dumps(response_json, indent=4, sort_keys=True))
# Out:
# {
#     "avgTotalVolume": 2184449,
#     "calculationPrice": "close",
#     "change": 1.03,
#     "changePercent": 0.00515,
#     "close": 200.89,
#     "closeTime": 1552078967843,
#     "companyName": "3M Co.",
#     "delayedPrice": null,
#     "delayedPriceTime": null,
#     "extendedChange": 0.01,
#     "extendedChangePercent": 5e-05,
#     "extendedPrice": 200.9,
#     "extendedPriceTime": 1552171077847,
#     "high": null,
#     "iexAskPrice": null,
#     "iexAskSize": null,
#     "iexBidPrice": null,
#     "iexBidSize": null,
#     "iexLastUpdated": null,
#     "iexMarketPercent": null,
#     "iexRealtimePrice": null,
#     "iexRealtimeSize": null,
#     "iexVolume": null,
#     "latestPrice": 200.89,
#     "latestSource": "Close",
#     "latestTime": "March 8, 2019",
#     "latestUpdate": 1552078967843,
#     "latestVolume": 0,
#     "low": null,
#     "marketCap": 115672462000,
#     "open": null,
#     "openTime": null,
#     "peRatio": 22.06,
#     "previousClose": 199.86,
#     "symbol": "MMM",
#     "week52High": 243.1,
#     "week52Low": 176.87,
#     "ytdChange": 0.057206
# }
# {
#     "avgTotalVolume": 1702232,
#     "calculationPrice": "close",
#     "change": 0.15,
#     "changePercent": 0.00296,
#     "close": 50.87,
#     "closeTime": 1552078844434,
#     "companyName": "A. O. Smith Corp.",
#     "delayedPrice": 50.87,
#     "delayedPriceTime": 1552165249968,
#     "extendedChange": 0,
#     "extendedChangePercent": 0,
#     "extendedPrice": 50.87,
#     "extendedPriceTime": 1552078849968,
#     "high": 51,
#     "iexAskPrice": null,
#     "iexAskSize": null,
#     "iexBidPrice": null,
#     "iexBidSize": null,
#     "iexLastUpdated": null,
#     "iexMarketPercent": null,
#     "iexRealtimePrice": null,
#     "iexRealtimeSize": null,
#     "iexVolume": null,
#     "latestPrice": 50.87,
#     "latestSource": "Close",
#     "latestTime": "March 8, 2019",
#     "latestUpdate": 1552078844434,
#     "latestVolume": 0,
#     "low": 50.26,
#     "marketCap": 8539238984,
#     "open": null,
#     "openTime": null,
#     "peRatio": 19.46,
#     "previousClose": 50.72,
#     "symbol": "AOS",
#     "week52High": 66.85,
#     "week52Low": 40.34,
#     "ytdChange": 0.17319199999999998
# }
# {
#     "avgTotalVolume": 5821018,
#     "calculationPrice": "close",
#     "change": -0.17,
#     "changePercent": -0.00221,
#     "close": 76.63,
#     "closeTime": 1552078879042,
#     "companyName": "Abbott Laboratories",
#     "delayedPrice": null,
#     "delayedPriceTime": null,
#     "extendedChange": -0.01,
#     "extendedChangePercent": -0.00013,
#     "extendedPrice": 76.62,
#     "extendedPriceTime": 1552176993906,
#     "high": null,
#     "iexAskPrice": null,
#     "iexAskSize": null,
#     "iexBidPrice": null,
#     "iexBidSize": null,
#     "iexLastUpdated": null,
#     "iexMarketPercent": null,
#     "iexRealtimePrice": null,
#     "iexRealtimeSize": null,
#     "iexVolume": null,
#     "latestPrice": 76.63,
#     "latestSource": "Close",
#     "latestTime": "March 8, 2019",
#     "latestUpdate": 1552078879042,
#     "latestVolume": 0,
#     "low": null,
#     "marketCap": 134598296100,
#     "open": null,
#     "openTime": null,
#     "peRatio": 56.99,
#     "previousClose": 76.8,
#     "symbol": "ABT",
#     "week52High": 78.97,
#     "week52Low": 56.81,
#     "ytdChange": 0.10038
# }
# {
#     "avgTotalVolume": 7264245,
#     "calculationPrice": "close",
#     "change": -0.66,
#     "changePercent": -0.00844,
#     "close": 77.58,
#     "closeTime": 1552079029562,
#     "companyName": "AbbVie, Inc.",
#     "delayedPrice": null,
#     "delayedPriceTime": null,
#     "extendedChange": 0.16,
#     "extendedChangePercent": 0.00206,
#     "extendedPrice": 77.74,
#     "extendedPriceTime": 1552172621469,
#     "high": null,
#     "iexAskPrice": null,
#     "iexAskSize": null,
#     "iexBidPrice": null,
#     "iexBidSize": null,
#     "iexLastUpdated": null,
#     "iexMarketPercent": null,
#     "iexRealtimePrice": null,
#     "iexRealtimeSize": null,
#     "iexVolume": null,
#     "latestPrice": 77.58,
#     "latestSource": "Close",
#     "latestTime": "March 8, 2019",
#     "latestUpdate": 1552079029562,
#     "latestVolume": 0,
#     "low": null,
#     "marketCap": 114436706400,
#     "open": null,
#     "openTime": null,
#     "peRatio": 21.67,
#     "previousClose": 78.24,
#     "symbol": "ABBV",
#     "week52High": 121.45,
#     "week52Low": 75.77,
#     "ytdChange": -0.139001
# }
# {
#     "avgTotalVolume": 1807020,
#     "calculationPrice": "close",
#     "change": -0.16,
#     "changePercent": -0.00099,
#     "close": 161.69,
#     "closeTime": 1552078955760,
#     "companyName": "Accenture Plc",
#     "delayedPrice": 161.69,
#     "delayedPriceTime": 1552166241298,
#     "extendedChange": 0,
#     "extendedChangePercent": 0,
#     "extendedPrice": 161.69,
#     "extendedPriceTime": 1552079841298,
#     "high": 161.81,
#     "iexAskPrice": null,
#     "iexAskSize": null,
#     "iexBidPrice": null,
#     "iexBidSize": null,
#     "iexLastUpdated": null,
#     "iexMarketPercent": null,
#     "iexRealtimePrice": null,
#     "iexRealtimeSize": null,
#     "iexVolume": null,
#     "latestPrice": 161.69,
#     "latestSource": "Close",
#     "latestTime": "March 8, 2019",
#     "latestUpdate": 1552078955760,
#     "latestVolume": 0,
#     "low": 160.5,
#     "marketCap": 103069128810,
#     "open": null,
#     "openTime": null,
#     "peRatio": 24.35,
#     "previousClose": 161.85,
#     "symbol": "ACN",
#     "week52High": 175.64,
#     "week52Low": 132.63,
#     "ytdChange": 0.149092
# }
# {
#     "avgTotalVolume": 16329260,
#     "calculationPrice": "close",
#     "change": 0.61,
#     "changePercent": 0.01473,
#     "close": 42.03,
#     "closeTime": 1552078800458,
#     "companyName": "Activision Blizzard, Inc.",
#     "delayedPrice": null,
#     "delayedPriceTime": null,
#     "extendedChange": -0.1,
#     "extendedChangePercent": -0.00238,
#     "extendedPrice": 41.93,
#     "extendedPriceTime": 1552172167085,
#     "high": null,
#     "iexAskPrice": null,
#     "iexAskSize": null,
#     "iexBidPrice": null,
#     "iexBidSize": null,
#     "iexLastUpdated": null,
#     "iexMarketPercent": null,
#     "iexRealtimePrice": null,
#     "iexRealtimeSize": null,
#     "iexVolume": null,
#     "latestPrice": 42.03,
#     "latestSource": "Close",
#     "latestTime": "March 8, 2019",
#     "latestUpdate": 1552078800458,
#     "latestVolume": 0,
#     "low": null,
#     "marketCap": 32103943020,
#     "open": null,
#     "openTime": null,
#     "peRatio": 17.66,
#     "previousClose": 41.42,
#     "symbol": "ATVI",
#     "week52High": 84.68,
#     "week52Low": 39.85,
#     "ytdChange": -0.091585
# }
# {
#     "avgTotalVolume": 376079,
#     "calculationPrice": "close",
#     "change": -3.45,
#     "changePercent": -0.02607,
#     "close": 128.91,
#     "closeTime": 1552078921075,
#     "companyName": "Acuity Brands, Inc.",
#     "delayedPrice": null,
#     "delayedPriceTime": null,
#     "extendedChange": 0,
#     "extendedChangePercent": 0,
#     "extendedPrice": 128.91,
#     "extendedPriceTime": 1552169251704,
#     "high": null,
#     "iexAskPrice": null,
#     "iexAskSize": null,
#     "iexBidPrice": null,
#     "iexBidSize": null,
#     "iexLastUpdated": null,
#     "iexMarketPercent": null,
#     "iexRealtimePrice": null,
#     "iexRealtimeSize": null,
#     "iexVolume": null,
#     "latestPrice": 128.91,
#     "latestSource": "Close",
#     "latestTime": "March 8, 2019",
#     "latestUpdate": 1552078921075,
#     "latestVolume": 0,
#     "low": null,
#     "marketCap": 5142477720,
#     "open": null,
#     "openTime": null,
#     "peRatio": 14.57,
#     "previousClose": 132.36,
#     "symbol": "AYI",
#     "week52High": 173.01,
#     "week52Low": 103.48,
#     "ytdChange": 0.09264900000000001
# }
# {
#     "avgTotalVolume": 2713470,
#     "calculationPrice": "close",
#     "change": -0.72,
#     "changePercent": -0.00282,
#     "close": 254.74,
#     "closeTime": 1552078800295,
#     "companyName": "Adobe, Inc.",
#     "delayedPrice": null,
#     "delayedPriceTime": null,
#     "extendedChange": 0.95,
#     "extendedChangePercent": 0.00373,
#     "extendedPrice": 255.69,
#     "extendedPriceTime": 1552179583336,
#     "high": null,
#     "iexAskPrice": null,
#     "iexAskSize": null,
#     "iexBidPrice": null,
#     "iexBidSize": null,
#     "iexLastUpdated": null,
#     "iexMarketPercent": null,
#     "iexRealtimePrice": null,
#     "iexRealtimeSize": null,
#     "iexVolume": null,
#     "latestPrice": 254.74,
#     "latestSource": "Close",
#     "latestTime": "March 8, 2019",
#     "latestUpdate": 1552078800295,
#     "latestVolume": 0,
#     "low": null,
#     "marketCap": 124597155100,
#     "open": null,
#     "openTime": null,
#     "peRatio": 48.25,
#     "previousClose": 255.46,
#     "symbol": "ADBE",
#     "week52High": 277.61,
#     "week52Low": 204.95,
#     "ytdChange": 0.131526
# }
# {
#     "avgTotalVolume": 1316763,
#     "calculationPrice": "close",
#     "change": -2.36,
#     "changePercent": -0.01531,
#     "close": 151.77,
#     "closeTime": 1552078923085,
#     "companyName": "Advance Auto Parts, Inc.",
#     "delayedPrice": null,
#     "delayedPriceTime": null,
#     "extendedChange": 0,
#     "extendedChangePercent": 0,
#     "extendedPrice": 151.77,
#     "extendedPriceTime": 1552169252569,
#     "high": null,
#     "iexAskPrice": null,
#     "iexAskSize": null,
#     "iexBidPrice": null,
#     "iexBidSize": null,
#     "iexLastUpdated": null,
#     "iexMarketPercent": null,
#     "iexRealtimePrice": null,
#     "iexRealtimeSize": null,
#     "iexVolume": null,
#     "latestPrice": 151.77,
#     "latestSource": "Close",
#     "latestTime": "March 8, 2019",
#     "latestUpdate": 1552078923085,
#     "latestVolume": 0,
#     "low": null,
#     "marketCap": 10877355900,
#     "open": null,
#     "openTime": null,
#     "peRatio": 26.44,
#     "previousClose": 154.13,
#     "symbol": "AAP",
#     "week52High": 186.15,
#     "week52Low": 102.15,
#     "ytdChange": -0.054254
# }
# {
#     "avgTotalVolume": 78886911,
#     "calculationPrice": "close",
#     "change": -0.07,
#     "changePercent": -0.00317,
#     "close": 22.01,
#     "closeTime": 1552078800598,
#     "companyName": "Advanced Micro Devices, Inc.",
#     "delayedPrice": null,
#     "delayedPriceTime": null,
#     "extendedChange": 0.13,
#     "extendedChangePercent": 0.00591,
#     "extendedPrice": 22.14,
#     "extendedPriceTime": 1552179596691,
#     "high": null,
#     "iexAskPrice": null,
#     "iexAskSize": null,
#     "iexBidPrice": null,
#     "iexBidSize": null,
#     "iexLastUpdated": null,
#     "iexMarketPercent": null,
#     "iexRealtimePrice": null,
#     "iexRealtimeSize": null,
#     "iexVolume": null,
#     "latestPrice": 22.01,
#     "latestSource": "Close",
#     "latestTime": "March 8, 2019",
#     "latestUpdate": 1552078800598,
#     "latestVolume": 0,
#     "low": null,
#     "marketCap": 22126653000,
#     "open": null,
#     "openTime": null,
#     "peRatio": 64.74,
#     "previousClose": 22.08,
#     "symbol": "AMD",
#     "week52High": 34.14,
#     "week52Low": 9.04,
#     "ytdChange": 0.165709
# }
# {
#     "avgTotalVolume": 5768327,
#     "calculationPrice": "close",
#     "change": 0.03,
#     "changePercent": 0.0017,
#     "close": 17.7,
#     "closeTime": 1552078998841,
#     "companyName": "The AES Corp.",
#     "delayedPrice": null,
#     "delayedPriceTime": null,
#     "extendedChange": 0.61,
#     "extendedChangePercent": 0.03446,
#     "extendedPrice": 18.31,
#     "extendedPriceTime": 1552177668803,
#     "high": null,
#     "iexAskPrice": null,
#     "iexAskSize": null,
#     "iexBidPrice": null,
#     "iexBidSize": null,
#     "iexLastUpdated": null,
#     "iexMarketPercent": null,
#     "iexRealtimePrice": null,
#     "iexRealtimeSize": null,
#     "iexVolume": null,
#     "latestPrice": 17.7,
#     "latestSource": "Close",
#     "latestTime": "March 8, 2019",
#     "latestUpdate": 1552078998841,
#     "latestVolume": 0,
#     "low": null,
#     "marketCap": 11724550800,
#     "open": null,
#     "openTime": null,
#     "peRatio": 9.75,
#     "previousClose": 17.67,
#     "symbol": "AES",
#     "week52High": 17.95,
#     "week52Low": 10.49,
#     "ytdChange": 0.24993700000000002
# }
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-13-2a6f01f46c13> in <module>()
#       3 for symbol in symbols:
#       4     response = requests.get(f'https://cloud.iexapis.com/beta/stock/{symbol}/quote?token={API_KEY}')
# ----> 5     response_json = response.json()
#       6     print(json.dumps(response_json, indent=4, sort_keys=True))
#
# /anaconda3/lib/python3.6/site-packages/requests/models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# /anaconda3/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# /anaconda3/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# /anaconda3/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
